# %% [markdown]
# # Importing relevant libraries

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Importing data

# %%
shark_attacks = pd.read_csv('C:/Users/pfaprado/Documents/IronHack/2021-01-22-project-shark-attack/attacks.csv', encoding='latin1')

# %% [markdown]
# # Preliminary analysis of data

# %%
# Let's show all the columns available through a max_columns = None and a head method.

pd.options.display.max_columns = None
shark_attacks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2  original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25          6303.0         NaN         NaN
# 1    2018.06.18          6302.0         NaN         NaN
# 2    2018.06.09          6301.0         NaN         NaN
# 3    2018.06.08          6300.0         NaN         NaN
# 4    2018.06.04          6299.0         NaN         NaN

# %% [markdown]
# ## Size of the dataframe

# %%
# Let's check the number of elements in our dataframe.

shark_attacks.size

# We have about 617352 elements.
# Out:
# 617352

# %% [markdown]
# ## Shape of the dataframe

# %%
# Let's check the shape of our dataframe.

shark_attacks.shape

# We have 24723 entries of 24 types of data.
# Out:
# (25723, 24)

# %% [markdown]
# ## Null-count and data types of the dataframe

# %%
# Let's check the non-null count and type of our data.

shark_attacks.info()

# Too many data entries without many infos such as Age, Time, Sex, Fatal, etc. Last columns can't be used.
# Year is a float64, should have been an integer.
# Age should have been specified as integer.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href formula            6301 non-null   object
#  18  href                    6302 non-null   object
#  19  Case Number.1           6302 non-null   object
#  20  Case Number.2           6302 non-null   object
#  21  original order          6309 non-null   float64
#  22  Unnamed: 22             1 non-null      object
#  23  Unnamed: 23             2 non-null      object
# dtypes: float64(2), object(22)
# memory usage: 4.7+ MB

# %%
# Specifically, about the types of data columns.

shark_attacks.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# Unnamed: 22                object
# Unnamed: 23                object
# dtype: object

# %% [markdown]
# ## Columns of the dataframe

# %%
# Let's check all the columns availables. There are a bunch of columns with strange names at the end.

shark_attacks.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# Let's check how many nulls we have in our dataset in each column.

null_cols = shark_attacks.isnull().sum()

null_cols
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %% [markdown]
# # Jaws Adventures: marketing shark feeding

# %%
"""
Our company, "Jaws Adventures", offers scuba diving for people.
We would like to analyse and market a new product: shark feeding.
However people may express distress to the idea of feeding sharks and the risks involved.
Let's analyse whether feeding sharks is safer than other activities already offered by our company.
"""

"""
For this, we will need to pull the data from columns:
- Activity (categorical)
- Fatal (Y/N) (categorical, binary: Y/N)

However, we know that the database is kind of messy, so we will need to do some data wrangling (cleaning) before.
"""

fatality_activity = shark_attacks[['Activity','Fatal (Y/N)']]

fatality_activity
# Out:
#           Activity Fatal (Y/N)
# 0         Paddling           N
# 1         Standing           N
# 2          Surfing           N
# 3          Surfing           N
# 4      Free diving           N
# ...            ...         ...
# 25718          NaN         NaN
# 25719          NaN         NaN
# 25720          NaN         NaN
# 25721          NaN         NaN
# 25722          NaN         NaN
#
# [25723 rows x 2 columns]

# %%
# Let's count all the occurrences present in the column Fatal.

shark_attacks['Fatal (Y/N)'].value_counts()

# Highest portion of shark attacks are non-fatal.
# Out:
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# y             1
# 2017          1
# M             1
# N             1
# Name: Fatal (Y/N), dtype: int64

# %%
shark_attacks['Activity'].value_counts()

# Highest portion occurred during surfing, swimming or fishing (apparently).
# !However there are way too many categories to affirm anything at this point!
# Out:
# Surfing                                                                971
# Swimming                                                               869
# Fishing                                                                431
# Spearfishing                                                           333
# Bathing                                                                162
#                                                                       ...
# Collecting marine specimens                                              1
# Harpooning turtles                                                       1
# Standing on his hands                                                    1
# Fishing from rocks, swept out to sea by large wave & treading water      1
# Helmet diving in Miami Seaquarium                                        1
# Name: Activity, Length: 1532, dtype: int64

# %%
# Let's understand the cases where the entries are null for Activity.

null_display_activity = shark_attacks[shark_attacks['Activity'].isnull() == True]
null_display_activity

# There is no apparent reason or correlation between null entries of Activity to other categories.
# Out:
#         Case Number         Date    Year        Type    Country  \
# 47       2018.01.28  28-Jan-2018  2018.0  Unprovoked  AUSTRALIA
# 108    2017.07.29.a  29-Jul-2017  2017.0  Unprovoked        USA
# 112    2017.07.23.b  23-Jul-2017  2017.0  Unprovoked        USA
# 114      2017.07.22  22-Jul-2017  2017.0  Unprovoked        USA
# 154    2017.04.17.b  17-Apr-2017  2017.0  Unprovoked        USA
# ...             ...          ...     ...         ...        ...
# 25718           NaN          NaN     NaN         NaN        NaN
# 25719           NaN          NaN     NaN         NaN        NaN
# 25720           NaN          NaN     NaN         NaN        NaN
# 25721           NaN          NaN     NaN         NaN        NaN
# 25722            xx          NaN     NaN         NaN        NaN
#
#                     Area                             Location Activity  \
# 47     Western Australia                             Cone Bay      NaN
# 108       South Carolina  DeBordieu Colony, Georgetown County      NaN
# 112           New Jersey                              Ventnor      NaN
# 114              Florida          Snipes Point, Monroe County      NaN
# 154              Florida        Daytona Beach, Volusia County      NaN
# ...                  ...                                  ...      ...
# 25718                NaN                                  NaN      NaN
# 25719                NaN                                  NaN      NaN
# 25720                NaN                                  NaN      NaN
# 25721                NaN                                  NaN      NaN
# 25722                NaN                                  NaN      NaN
#
#                  Name Sex   Age                             Injury  \
# 47               male    M   18              Injuries to right leg
# 108        female x 2    F   12  Bite to left thigh / minor injury
# 112    Isabella Smith    F  NaN               Minor injury to hand
# 114            female    F   40                        Foot bitten
# 154               NaN  NaN  NaN             Minor bite to the foot
# ...               ...  ...  ...                                ...
# 25718             NaN  NaN  NaN                                NaN
# 25719             NaN  NaN  NaN                                NaN
# 25720             NaN  NaN  NaN                                NaN
# 25721             NaN  NaN  NaN                                NaN
# 25722             NaN  NaN  NaN                                NaN
#
#       Fatal (Y/N)       Time             Species   \
# 47              N      08h00           Bull shark
# 108             N  Afternoon                  NaN
# 112             N        NaN  Sandtiger shark  2'
# 114             N      12h30      "A small shark"
# 154             N  Afternoon                  NaN
# ...           ...        ...                  ...
# 25718         NaN        NaN                  NaN
# 25719         NaN        NaN                  NaN
# 25720         NaN        NaN                  NaN
# 25721         NaN        NaN                  NaN
# 25722         NaN        NaN                  NaN
#
#                       Investigator or Source                          pdf  \
# 47                    ABC.net.au, 01/28/2018       2018.01.28-ConeBay.pdf
# 108                        C. Creswell, GSAF  2017.07.29.a-Georgetown.pdf
# 112                                 A. Smith       2017.07.23.b-Smith.pdf
# 114                     NBC Miami, 7/23/2017          2017.07.22-Keys.pdf
# 154    Daytona Beach News-Journal, 4/17/2017     2017.04.17.b-Volusia.pdf
# ...                                      ...                          ...
# 25718                                    NaN                          NaN
# 25719                                    NaN                          NaN
# 25720                                    NaN                          NaN
# 25721                                    NaN                          NaN
# 25722                                    NaN                          NaN
#
#                                             href formula  \
# 47     http://sharkattackfile.net/spreadsheets/pdf_di...
# 108    http://sharkattackfile.net/spreadsheets/pdf_di...
# 112    http://sharkattackfile.net/spreadsheets/pdf_di...
# 114    http://sharkattackfile.net/spreadsheets/pdf_di...
# 154    http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 47     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.01.28
# 108    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.07.29.a
# 112    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.07.23.b
# 114    http://sharkattackfile.net/spreadsheets/pdf_di...    2017.07.22
# 154    http://sharkattackfile.net/spreadsheets/pdf_di...  2017.04.17.b
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2  original order Unnamed: 22 Unnamed: 23
# 47       2018.01.28          6256.0         NaN         NaN
# 108    2017.07.29.a          6195.0         NaN         NaN
# 112    2017.07.23.b          6191.0         NaN         NaN
# 114      2017.07.22          6189.0         NaN         NaN
# 154    2017.04.17.b          6149.0         NaN         NaN
# ...             ...             ...         ...         ...
# 25718           NaN             NaN         NaN         NaN
# 25719           NaN             NaN         NaN         NaN
# 25720           NaN             NaN         NaN         NaN
# 25721           NaN             NaN         NaN         NaN
# 25722           NaN             NaN         NaN         NaN
#
# [19965 rows x 24 columns]

# %%
# Let's understand the cases where the entries are null for Fatal.

null_display_fatal = shark_attacks[shark_attacks['Fatal (Y/N)'].isnull() == True]
null_display_fatal

# There is no apparent reason or correlation between null entries of Fatal to other categories.
# Out:
#         Case Number         Date    Year        Type       Country  \
# 27     2018.04.15.c  15-Apr-2018  2018.0  Unprovoked        BRAZIL
# 76       2017.10.01  01-Oct-2017  2017.0     Invalid  SOUTH AFRICA
# 79     2017.09.24.b  24-Sep-2017  2017.0     Invalid           USA
# 84     2017.09.15.b  15-Sep-2017  2017.0     Invalid  SOUTH AFRICA
# 98     2017.08.26.b  26-Aug-2017  2017.0     Invalid         SPAIN
# ...             ...          ...     ...         ...           ...
# 25718           NaN          NaN     NaN         NaN           NaN
# 25719           NaN          NaN     NaN         NaN           NaN
# 25720           NaN          NaN     NaN         NaN           NaN
# 25721           NaN          NaN     NaN         NaN           NaN
# 25722            xx          NaN     NaN         NaN           NaN
#
#                         Area         Location      Activity            Name  \
# 27                Pernambuco          Piedade      Swimming   Pablo de Melo
# 76     Western Cape Province      Dyer Island  Scuba Diving    Bradley Fick
# 79                  New York         Rockaway       Surfing  Michah Behrend
# 84     Western Cape Province          Hawston  Scuba Diving      Wayon Love
# 98                 Castellón  Grao de Moncofa      Swimming          female
# ...                      ...              ...           ...             ...
# 25718                    NaN              NaN           NaN             NaN
# 25719                    NaN              NaN           NaN             NaN
# 25720                    NaN              NaN           NaN             NaN
# 25721                    NaN              NaN           NaN             NaN
# 25722                    NaN              NaN           NaN             NaN
#
#       Sex   Age                                             Injury  \
# 27       M   34  Multiple severe injuries to arms and leg, leg ...
# 76       M   31                                              FATAL
# 79       M   33             Lacerations to right ankle, foot & toe
# 84       M   25      FATAL, but death was probably due to drowning
# 98       F   11                           Lacerations to left foot
# ...    ...  ...                                                ...
# 25718  NaN  NaN                                                NaN
# 25719  NaN  NaN                                                NaN
# 25720  NaN  NaN                                                NaN
# 25721  NaN  NaN                                                NaN
# 25722  NaN  NaN                                                NaN
#
#       Fatal (Y/N)       Time                             Species   \
# 27            NaN        NaN                                  NaN
# 76            NaN        NaN  Death may have been due to drowning
# 79            NaN      15h30                         Questionable
# 84            NaN  Afternoon                                  NaN
# 98            NaN     Midday       Shark involvement questionable
# ...           ...        ...                                  ...
# 25718         NaN        NaN                                  NaN
# 25719         NaN        NaN                                  NaN
# 25720         NaN        NaN                                  NaN
# 25721         NaN        NaN                                  NaN
# 25722         NaN        NaN                                  NaN
#
#                      Investigator or Source                       pdf  \
# 27                         Globo, 4/16/2018   2018.04.15.c-deMelo.pdf
# 76                  All Africa, 10/11/2017        2017.10.01-Fick.pdf
# 79                S. Curatolo-Wageman, GSAF  2017.09.24.b-Behrend.pdf
# 84                     Ground Up, 9/20/2017     2017.09.15.b-Love.pdf
# 98     El Periodico Mediterraneo, 8/27/2017    2017.08.26.b-Spain.pdf
# ...                                     ...                       ...
# 25718                                   NaN                       NaN
# 25719                                   NaN                       NaN
# 25720                                   NaN                       NaN
# 25721                                   NaN                       NaN
# 25722                                   NaN                       NaN
#
#                                             href formula  \
# 27     http://sharkattackfile.net/spreadsheets/pdf_di...
# 76     http://sharkattackfile.net/spreadsheets/pdf_di...
# 79     http://sharkattackfile.net/spreadsheets/pdf_di...
# 84     http://sharkattackfile.net/spreadsheets/pdf_di...
# 98     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 25718                                                NaN
# 25719                                                NaN
# 25720                                                NaN
# 25721                                                NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 27     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.15.c
# 76     http://sharkattackfile.net/spreadsheets/pdf_di...    2017.10.01
# 79     http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.24.b
# 84     http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.15.b
# 98     http://sharkattackfile.net/spreadsheets/pdf_di...  2017.08.26.b
# ...                                                  ...           ...
# 25718                                                NaN           NaN
# 25719                                                NaN           NaN
# 25720                                                NaN           NaN
# 25721                                                NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2  original order Unnamed: 22 Unnamed: 23
# 27     2018.04.15.c          6276.0         NaN         NaN
# 76       2017.10.01          6227.0         NaN         NaN
# 79     2017.09.24.b          6224.0         NaN         NaN
# 84     2017.09.15.b          6219.0         NaN         NaN
# 98     2017.08.26.b          6205.0         NaN         NaN
# ...             ...             ...         ...         ...
# 25718           NaN             NaN         NaN         NaN
# 25719           NaN             NaN         NaN         NaN
# 25720           NaN             NaN         NaN         NaN
# 25721           NaN             NaN         NaN         NaN
# 25722           NaN             NaN         NaN         NaN
#
# [19960 rows x 24 columns]

# %%
# Let's check for duplicates in our database and remove them:

before = len(shark_attacks)
shark_attacks = shark_attacks.drop_duplicates()
after = len(shark_attacks)
print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  19411

# %%
# That's how our database is now:

shark_attacks.head(7)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
#
#                          Location      Activity                    Name Sex   \
# 0     Oceanside, San Diego County      Paddling             Julie Wolfe    F
# 1  St. Simon Island, Glynn County      Standing         Adyson McNeely     F
# 2                    Habush, Oahu       Surfing             John Denges    M
# 3              Arrawarra Headland       Surfing                    male    M
# 4                        La Ticla   Free diving          Gustavo Ramos     M
# 5              Flat Rock, Ballina  Kite surfing                 Chris
#     M
# 6           Piedade Beach, Recife      Swimming  Jose Ernesto da Silva     M
#
#    Age                                             Injury Fatal (Y/N)  \
# 0   57  No injury to occupant, outrigger canoe and pad...           N
# 1   11                         Minor injury to left thigh           N
# 2   48       Injury to left lower leg from surfboard skeg           N
# 3  NaN                          Minor injury to lower leg           N
# 4  NaN  Lacerations to leg & hand shark PROVOKED INCIDENT           N
# 5  NaN                            No injury, board bitten           N
# 6   18                                              FATAL           Y
#
#              Time         Species           Investigator or Source  \
# 0           18h00      White shark                R. Collier, GSAF
# 1   14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2           07h45              NaN  K.McMurray, TrackingSharks.com
# 3             NaN        2 m shark                  B. Myatt, GSAF
# 4             NaN  Tiger shark, 3m                       A .Kipper
# 5             NaN              NaN       Daily Telegraph, 6/4/2018
# 6  Late afternoon      Tiger shark  Diario de Pernambuco, 6/4/2018
#
#                          pdf  \
# 0       2018.06.25-Wolfe.pdf
# 1     2018.06.18-McNeely.pdf
# 2      2018.06.09-Denges.pdf
# 3   2018.06.08-Arrawarra.pdf
# 4       2018.06.04-Ramos.pdf
# 5  2018.06.03.b-FlatRock.pdf
# 6   2018.06.03.a-daSilva.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# 5  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.b
# 6  http://sharkattackfile.net/spreadsheets/pdf_di...  2018.06.03.a
#
#   Case Number.2  original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25          6303.0         NaN         NaN
# 1    2018.06.18          6302.0         NaN         NaN
# 2    2018.06.09          6301.0         NaN         NaN
# 3    2018.06.08          6300.0         NaN         NaN
# 4    2018.06.04          6299.0         NaN         NaN
# 5  2018.06.03.b          6298.0         NaN         NaN
# 6  2018.06.03.a          6297.0         NaN         NaN

# %% [markdown]
# ## Data Cleaning: 'Fatal (Y/N)'

# %%
# Let's check the unique values of the column Fatal (Y/N) and its incidence in our database.

print(f"""
These are the occurrences of the values for Fatal (Y/N):
{shark_attacks['Fatal (Y/N)'].value_counts()}
""")

print(f"""
These are the unique values of the Fatal (Y/N) column:
{set(shark_attacks['Fatal (Y/N)'])}

We will need to standardize it all in Y and N.
To do this, we will need to:

1. Check rows of data where anything else than Y/N appears (UNKNOWN, 2017, nan, M... about 73 occurrences).
    We may be able to attribute it to Y/N if Fatal/FATAL appears/fatal appears in other columns of the entry.
2. If not, drop the rows of these data values.
3. Transform the series from the dataframe into a list.
4. Upper case the strings.
5. Strip the strings of spaces after and before the character.
""")
# Out:
# These are the occurrences of the values for Fatal (Y/N):
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# M             1
# y             1
# 2017          1
# N             1
# Name: Fatal (Y/N), dtype: int64
#
#
# These are the unique values of the Fatal (Y/N) column:
# {nan, 'UNKNOWN', 'y', 'N', 'Y', 'M', ' N', '2017', 'N '}
#
# We will need to standardize it all in Y and N.
# To do this, we will need to:
#
# 1. Check rows of data where anything else than Y/N appears (UNKNOWN, 2017, nan, M... about 73 occurrences).
#     We may be able to attribute it to Y/N if Fatal/FATAL appears/fatal appears in other columns of the entry.
# 2. If not, drop the rows of these data values.
# 3. Transform the series from the dataframe into a list.
# 4. Upper case the strings.
# 5. Strip the strings of spaces after and before the character.

# %% [markdown]
# ### Checking uniques.

# %%
#Let's examine the case of 2017. There is only one entry classified as 2017.

case_2017_list = shark_attacks.loc[shark_attacks['Fatal (Y/N)'] == '2017']

case_2017_list

# As there is no information regarding the survivability on other columns,
# we will dismiss this entry in the dropping section.
# Out:
#     Case Number         Date    Year      Type Country      Area  Location  \
# 786  2012.06.10  10-Jun-2012  2012.0  Provoked   ITALY  Sardinia  Muravera
#
#                                             Activity          Name Sex  Age  \
# 786  Attempting to rescue an injured & beached shark  Giorgio Zara    M  57
#
#                                        Injury Fatal (Y/N)     Time  \
# 786  Lower left leg injured PROVOKED ACCIDENT        2017  Morning
#
#              Species  Investigator or Source                  pdf  \
# 786  Blue shark, 2.5m    D. Puddo, 6/11/2012  2012.06.10-Zara.pdf
#
#                                           href formula  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...    2012.06.10
#
#     Case Number.2  original order Unnamed: 22 Unnamed: 23
# 786    2012.06.10          5517.0         NaN         NaN

# %%
# Let's examine the case of UNKNOWN. There are many entries classified as UNKNOWN.

case_UNKNOWN = shark_attacks.loc[shark_attacks['Fatal (Y/N)'] == 'UNKNOWN']
print(case_UNKNOWN)

# Printaremos também os índices referentes à entrada UNKNOWN. Futuramente retiraremos as linhas com base nessa lista.

case_UNKNOWN_list = list(case_UNKNOWN.index)
print(case_UNKNOWN_list)

# Examining the set of unique values of injury, we don't have any other relevant info on the fatality of the entries.
# So we can't take any action to classify these entries neither as Y nor as N.

set(case_UNKNOWN['Injury'])

# We will dismiss these entries since there is no info about fatality in the adjacent columns.
# Out:
#        Case Number           Date    Year        Type    Country  \
# 624     2013.09.08    08-Sep-2013  2013.0  Unprovoked        USA
# 1270  2008.04.20.a    20-Apr-2008  2008.0  Unprovoked  AUSTRALIA
# 2250    1997.06.07    07-Jun-1997  1997.0  Unprovoked     BRAZIL
# 2260    1997.02.21    21-Feb-1997  1997.0  Unprovoked        USA
# 2267    1996.12.29    29-Dec-1996  1996.0  Unprovoked  AUSTRALIA
# ...            ...            ...     ...         ...        ...
# 6167  1617.00.00.R  Reported 1617  1617.0  Unprovoked      INDIA
# 6169    1595.00.00           1595  1595.0  Unprovoked      INDIA
# 6171    1555.00.00           1555  1555.0  Unprovoked        NaN
# 6172    1554.00.00       Ca. 1554  1554.0  Unprovoked     FRANCE
# 6277       ND.0025    Before 1927     0.0  Unprovoked  AUSTRALIA
#
#                    Area                            Location  \
# 624      South Carolina  St. Helena Island, Beaufort County
# 1270    New South Wales                       Crescent Head
# 2250     Rio de Janeiro          Copacabana, Rio de Janeiro
# 2260             Hawaii                 Sunset Beach, O'ahu
# 2267         Queensland                        Coolum Beach
# ...                 ...                                 ...
# 6167        West Bengal                        Ganges Delta
# 6169             Kerala                        River Cochin
# 6171                NaN                                 NaN
# 6172  Nice & Marseilles                                 NaN
# 6277    New South Wales      Spectacle Island, Port Jackson
#
#                                                Activity  \
# 624                                                 NaN
# 1270                                                NaN
# 2250                                            Bathing
# 2260                                                NaN
# 2267                                            Surfing
# ...                                                 ...
# 6167                                                NaN
# 6169  Ship lay at anchor & man was working on its ru...
# 6171                                           Swimming
# 6172                                                NaN
# 6277                                                NaN
#
#                                Name Sex   Age  \
# 624                          female    F  NaN
# 1270                Jamie Adlington    M  NaN
# 2250              José Luiz Lipiani    M  NaN
# 2260                Gersome Perreno    M  NaN
# 2267                     Blair Hall    M   18
# ...                             ...  ...  ...
# 6167                  Indian people  NaN  NaN
# 6169                           male    M  NaN
# 6171                           male    M  NaN
# 6172          males (wearing armor)    M  NaN
# 6277  male, the Sergeant of Marines    M  NaN
#
#                                                  Injury Fatal (Y/N)   Time  \
# 624                                          No details     UNKNOWN    NaN
# 1270                                                NaN     UNKNOWN    NaN
# 2250                                                NaN     UNKNOWN    NaN
# 2260                                         No details     UNKNOWN    NaN
# 2267                                                NaN     UNKNOWN  18h00
# ...                                                 ...         ...    ...
# 6167                                                NaN     UNKNOWN    NaN
# 6169  Leg severed mid-thigh, hand severed, arm above...     UNKNOWN    NaN
# 6171                                                NaN     UNKNOWN    NaN
# 6172                                                NaN     UNKNOWN    NaN
# 6277                                                NaN     UNKNOWN    NaN
#
#                    Species                      Investigator or Source  \
# 624                     NaN                           WIS-TV, 9/9/2013
# 1270     Tiger shark, 2.3m                              T. Peake, GSAF
# 2250                    NaN                            Globo, 6/9/1997
# 2260                    NaN                                  G. Balazs
# 2267                    NaN            The Advertiser, 12/30/1996, p.3
# ...                     ...                                        ...
# 6167                    NaN    H. Edwards, p.31, citing Samuel Purchas
# 6169                    NaN  The Voyage of John Huyghen van Linschoten
# 6171                    NaN                               Olaus Magnus
# 6172  Possibly white sharks                               G. Rondelet
# 6277                    NaN                                  H. Capper
#
#                                   pdf  \
# 624          2013.09.08-St-Helena.pdf
# 1270       2008.04.20.a-Adlington.pdf
# 2250        1997.06.07-NV-Lipiani.pdf
# 2260        1997.02.21-NV-Perreno.pdf
# 2267         1996.12.29-BlairHall.pdf
# ...                               ...
# 6167           1617.00.00-Purchas.pdf
# 6169            1595.00.00-Cochin.pdf
# 6171    1555.00.00 - Olaus Magnus.pdf
# 6172          1554.00.00-Rondelet.pdf
# 6277  ND-0025-Sgt-SpectacleIsland.pdf
#
#                                            href formula  \
# 624   http://sharkattackfile.net/spreadsheets/pdf_di...
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2250  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2260  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2267  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6167  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6169  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6171  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6172  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6277  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 624   http://sharkattackfile.net/spreadsheets/pdf_di...    2013.09.08
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.04.20.a
# 2250  http://sharkattackfile.net/spreadsheets/pdf_di...    1997.06.07
# 2260  http://sharkattackfile.net/spreadsheets/pdf_di...    1997.02.21
# 2267  http://sharkattackfile.net/spreadsheets/pdf_di...    1996.12.29
# ...                                                 ...           ...
# 6167  http://sharkattackfile.net/spreadsheets/pdf_di...  1617.00.00.R
# 6169  http://sharkattackfile.net/spreadsheets/pdf_di...    1595.00.00
# 6171  http://sharkattackfile.net/spreadsheets/pdf_di...    1555.00.00
# 6172  http://sharkattackfile.net/spreadsheets/pdf_di...    1554.00.00
# 6277  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0025
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23
# 624     2013.09.08          5679.0         NaN         NaN
# 1270  2008.04.20.a          5033.0         NaN         NaN
# 2250    1997.06.07          4053.0         NaN         NaN
# 2260    1997.02.21          4043.0         NaN         NaN
# 2267    1996.12.29          4036.0         NaN         NaN
# ...            ...             ...         ...         ...
# 6167  1617.00.00.R           136.0         NaN         NaN
# 6169    1595.00.00           134.0         NaN         NaN
# 6171    1555.00.00           132.0         NaN         NaN
# 6172    1554.00.00           131.0         NaN         NaN
# 6277       ND.0025            26.0         NaN         NaN
#
# [71 rows x 24 columns]
# [624, 1270, 2250, 2260, 2267, 2295, 2307, 2323, 2328, 2388, 2404, 2409, 2648, 2650, 2661, 2806, 2882, 2900, 2943, 2996, 2998, 3006, 3038, 3041, 3298, 3396, 3411, 3429, 3434, 3507, 3545, 3552, 3712, 3774, 3794, 3838, 3841, 4060, 4208, 4256, 4269, 4310, 4323, 4517, 4689, 4786, 4787, 4976, 4998, 5029, 5159, 5270, 5347, 5409, 5555, 5615, 5653, 5656, 5674, 5708, 5709, 5998, 6081, 6153, 6165, 6166, 6167, 6169, 6171, 6172, 6277]
# {'"Painfully injured" but no details',
#  'Calf removed, not known if he survived ',
#  'Details unknown, possibly a PROVOKED INCIDENT',
#  'Involved a speared shark but no other details PROVOKED INCIDENT',
#  'Leg severed mid-thigh, hand severed, arm above elbow and part of buttocks. Not known if he survived',
#  'Man landed at Cape Levêque lighthouse in critical condition after being bitten by a shark. Not known if he survived.',
#  'No details',
#  'No details, "recovering in Darwin Hospital"',
#  'No details, it was the year the first settlers came ashore in Holdfast Bay, Port Pirie',
#  'No details, listed as PROVOKED INCIDENT',
#  'No injury',
#  'Severe bite to thigh. Not known if he survived',
#  'Shark involvement not confirmed',
#  'Unprovoked, but circumstances unknown',
#  nan}

# %%
# Let's examine the case of M. There is only one entry classified as M.

case_M = shark_attacks.loc[shark_attacks['Fatal (Y/N)'] == 'M']
print(case_M)

# Printaremos também os índices referentes à entrada M. Futuramente retiraremos as linhas com base nessa lista.

case_M_list = list(case_M.index)
print(case_M_list)

# It seems it was only a laceration and the input was supposed to be N, not M. We will change it to 'N' (not fatal).
# Out:
#       Case Number         Date    Year      Type           Country      Area  \
# 285  2016.04.18.b  18-Apr-2016  2016.0  Provoked  FRENCH POLYNESIA  Tuamotos
#
#          Location      Activity         Name Sex  Age  \
# 285  Makemo Atoll  Spearfishing  Hoata Iotua    M  22
#
#                                                 Injury Fatal (Y/N)     Time  \
# 285  Laceration to knee by speared shark PROVOKED I...           M  Morning
#
#                  Species  Investigator or Source                     pdf  \
# 285  Grey reef shark, 2 m   TNTV News, 4/19/2016  2016.04.18.b-Iotua.pdf
#
#                                           href formula  \
# 285  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href Case Number.1  \
# 285  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.04.18.b
#
#     Case Number.2  original order Unnamed: 22 Unnamed: 23
# 285  2016.04.18.b          6018.0         NaN         NaN
# [285]

# %%
# Showing all NaN in column Fatal (Y/N)

null_display_fatal = shark_attacks[shark_attacks['Fatal (Y/N)'].isnull() == True]
null_display_fatal
# Out:
#         Case Number         Date    Year        Type       Country  \
# 27     2018.04.15.c  15-Apr-2018  2018.0  Unprovoked        BRAZIL
# 76       2017.10.01  01-Oct-2017  2017.0     Invalid  SOUTH AFRICA
# 79     2017.09.24.b  24-Sep-2017  2017.0     Invalid           USA
# 84     2017.09.15.b  15-Sep-2017  2017.0     Invalid  SOUTH AFRICA
# 98     2017.08.26.b  26-Aug-2017  2017.0     Invalid         SPAIN
# ...             ...          ...     ...         ...           ...
# 6307              0          NaN     NaN         NaN           NaN
# 6308              0          NaN     NaN         NaN           NaN
# 6309              0          NaN     NaN         NaN           NaN
# 8702            NaN          NaN     NaN         NaN           NaN
# 25722            xx          NaN     NaN         NaN           NaN
#
#                         Area         Location      Activity            Name  \
# 27                Pernambuco          Piedade      Swimming   Pablo de Melo
# 76     Western Cape Province      Dyer Island  Scuba Diving    Bradley Fick
# 79                  New York         Rockaway       Surfing  Michah Behrend
# 84     Western Cape Province          Hawston  Scuba Diving      Wayon Love
# 98                 Castellón  Grao de Moncofa      Swimming          female
# ...                      ...              ...           ...             ...
# 6307                     NaN              NaN           NaN             NaN
# 6308                     NaN              NaN           NaN             NaN
# 6309                     NaN              NaN           NaN             NaN
# 8702                     NaN              NaN           NaN             NaN
# 25722                    NaN              NaN           NaN             NaN
#
#       Sex   Age                                             Injury  \
# 27       M   34  Multiple severe injuries to arms and leg, leg ...
# 76       M   31                                              FATAL
# 79       M   33             Lacerations to right ankle, foot & toe
# 84       M   25      FATAL, but death was probably due to drowning
# 98       F   11                           Lacerations to left foot
# ...    ...  ...                                                ...
# 6307   NaN  NaN                                                NaN
# 6308   NaN  NaN                                                NaN
# 6309   NaN  NaN                                                NaN
# 8702   NaN  NaN                                                NaN
# 25722  NaN  NaN                                                NaN
#
#       Fatal (Y/N)       Time                             Species   \
# 27            NaN        NaN                                  NaN
# 76            NaN        NaN  Death may have been due to drowning
# 79            NaN      15h30                         Questionable
# 84            NaN  Afternoon                                  NaN
# 98            NaN     Midday       Shark involvement questionable
# ...           ...        ...                                  ...
# 6307          NaN        NaN                                  NaN
# 6308          NaN        NaN                                  NaN
# 6309          NaN        NaN                                  NaN
# 8702          NaN        NaN                                  NaN
# 25722         NaN        NaN                                  NaN
#
#                      Investigator or Source                       pdf  \
# 27                         Globo, 4/16/2018   2018.04.15.c-deMelo.pdf
# 76                  All Africa, 10/11/2017        2017.10.01-Fick.pdf
# 79                S. Curatolo-Wageman, GSAF  2017.09.24.b-Behrend.pdf
# 84                     Ground Up, 9/20/2017     2017.09.15.b-Love.pdf
# 98     El Periodico Mediterraneo, 8/27/2017    2017.08.26.b-Spain.pdf
# ...                                     ...                       ...
# 6307                                    NaN                       NaN
# 6308                                    NaN                       NaN
# 6309                                    NaN                       NaN
# 8702                                    NaN                       NaN
# 25722                                   NaN                       NaN
#
#                                             href formula  \
# 27     http://sharkattackfile.net/spreadsheets/pdf_di...
# 76     http://sharkattackfile.net/spreadsheets/pdf_di...
# 79     http://sharkattackfile.net/spreadsheets/pdf_di...
# 84     http://sharkattackfile.net/spreadsheets/pdf_di...
# 98     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 27     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.15.c
# 76     http://sharkattackfile.net/spreadsheets/pdf_di...    2017.10.01
# 79     http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.24.b
# 84     http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.15.b
# 98     http://sharkattackfile.net/spreadsheets/pdf_di...  2017.08.26.b
# ...                                                  ...           ...
# 6307                                                 NaN           NaN
# 6308                                                 NaN           NaN
# 6309                                                 NaN           NaN
# 8702                                                 NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2  original order Unnamed: 22 Unnamed: 23
# 27     2018.04.15.c          6276.0         NaN         NaN
# 76       2017.10.01          6227.0         NaN         NaN
# 79     2017.09.24.b          6224.0         NaN         NaN
# 84     2017.09.15.b          6219.0         NaN         NaN
# 98     2017.08.26.b          6205.0         NaN         NaN
# ...             ...             ...         ...         ...
# 6307            NaN          6309.0         NaN         NaN
# 6308            NaN          6310.0         NaN         NaN
# 6309            NaN             NaN         NaN         NaN
# 8702            NaN             NaN         NaN         NaN
# 25722           NaN             NaN         NaN         NaN
#
# [549 rows x 24 columns]

# %%
# Let's examine the case of NaN. There are many entries like this.
# We will reclassify the values of NaN based on columns 'Injury' and 'Species' since it seems the data entrier
# had put some keywords such as FATAL and Death on these columns and could lead us to improve our dataset.

# Let's define a function to apply to our dataset, where we classify the values in Fatal_adjusted based on
# columns 'Injury' and 'Species', when they do have the info 'death' or 'fatal'.

# WARNING: column Species is written with a space at the end = 'Species '

def fatal_classifier(row):
    
    """
    Essa função classificará em N ou Y com base nas strings ou lista de strings encontradas
    nas colunas Injury e Species.
    """
    
    if row['Fatal (Y/N)'] == ('Y' or 'y'):
        return 'Y'
    
    elif row['Fatal (Y/N)'] == ('N' or 'n'):
        return 'N'
        
    elif pd.isnull(row['Fatal (Y/N)']) == True: 
        
        try:            
            Injury_match_list = re.findall('[fFdD][aAeE][tTaA][aAtT][lLhH]', row['Injury'])    #variações de 'death' e 'fatal'
            Species_match_list = re.findall('[fFdD][aAeE][tTaA][aAtT][lLhH]', row['Species '])    #variações de 'death' e 'fatal'
            
            if  len(Injury_match_list + Species_match_list) == 0:
                return 'N'
    
            else:
                return 'Y'
        
        except:
            return 'Non available'
        
        
    else:
        return row['Fatal (Y/N)']

    
shark_attacks['Fatal_adjusted'] = shark_attacks.apply(fatal_classifier, axis=1)


#print(shark_attacks['Fatal_adjusted'] == shark_attacks['Fatal (Y/N)'])

null_display_fatal = shark_attacks[shark_attacks['Fatal (Y/N)'].isnull() == True]
null_display_fatal
# Out:
#         Case Number         Date    Year        Type       Country  \
# 27     2018.04.15.c  15-Apr-2018  2018.0  Unprovoked        BRAZIL
# 76       2017.10.01  01-Oct-2017  2017.0     Invalid  SOUTH AFRICA
# 79     2017.09.24.b  24-Sep-2017  2017.0     Invalid           USA
# 84     2017.09.15.b  15-Sep-2017  2017.0     Invalid  SOUTH AFRICA
# 98     2017.08.26.b  26-Aug-2017  2017.0     Invalid         SPAIN
# ...             ...          ...     ...         ...           ...
# 6307              0          NaN     NaN         NaN           NaN
# 6308              0          NaN     NaN         NaN           NaN
# 6309              0          NaN     NaN         NaN           NaN
# 8702            NaN          NaN     NaN         NaN           NaN
# 25722            xx          NaN     NaN         NaN           NaN
#
#                         Area         Location      Activity            Name  \
# 27                Pernambuco          Piedade      Swimming   Pablo de Melo
# 76     Western Cape Province      Dyer Island  Scuba Diving    Bradley Fick
# 79                  New York         Rockaway       Surfing  Michah Behrend
# 84     Western Cape Province          Hawston  Scuba Diving      Wayon Love
# 98                 Castellón  Grao de Moncofa      Swimming          female
# ...                      ...              ...           ...             ...
# 6307                     NaN              NaN           NaN             NaN
# 6308                     NaN              NaN           NaN             NaN
# 6309                     NaN              NaN           NaN             NaN
# 8702                     NaN              NaN           NaN             NaN
# 25722                    NaN              NaN           NaN             NaN
#
#       Sex   Age                                             Injury  \
# 27       M   34  Multiple severe injuries to arms and leg, leg ...
# 76       M   31                                              FATAL
# 79       M   33             Lacerations to right ankle, foot & toe
# 84       M   25      FATAL, but death was probably due to drowning
# 98       F   11                           Lacerations to left foot
# ...    ...  ...                                                ...
# 6307   NaN  NaN                                                NaN
# 6308   NaN  NaN                                                NaN
# 6309   NaN  NaN                                                NaN
# 8702   NaN  NaN                                                NaN
# 25722  NaN  NaN                                                NaN
#
#       Fatal (Y/N)       Time                             Species   \
# 27            NaN        NaN                                  NaN
# 76            NaN        NaN  Death may have been due to drowning
# 79            NaN      15h30                         Questionable
# 84            NaN  Afternoon                                  NaN
# 98            NaN     Midday       Shark involvement questionable
# ...           ...        ...                                  ...
# 6307          NaN        NaN                                  NaN
# 6308          NaN        NaN                                  NaN
# 6309          NaN        NaN                                  NaN
# 8702          NaN        NaN                                  NaN
# 25722         NaN        NaN                                  NaN
#
#                      Investigator or Source                       pdf  \
# 27                         Globo, 4/16/2018   2018.04.15.c-deMelo.pdf
# 76                  All Africa, 10/11/2017        2017.10.01-Fick.pdf
# 79                S. Curatolo-Wageman, GSAF  2017.09.24.b-Behrend.pdf
# 84                     Ground Up, 9/20/2017     2017.09.15.b-Love.pdf
# 98     El Periodico Mediterraneo, 8/27/2017    2017.08.26.b-Spain.pdf
# ...                                     ...                       ...
# 6307                                    NaN                       NaN
# 6308                                    NaN                       NaN
# 6309                                    NaN                       NaN
# 8702                                    NaN                       NaN
# 25722                                   NaN                       NaN
#
#                                             href formula  \
# 27     http://sharkattackfile.net/spreadsheets/pdf_di...
# 76     http://sharkattackfile.net/spreadsheets/pdf_di...
# 79     http://sharkattackfile.net/spreadsheets/pdf_di...
# 84     http://sharkattackfile.net/spreadsheets/pdf_di...
# 98     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 6307                                                 NaN
# 6308                                                 NaN
# 6309                                                 NaN
# 8702                                                 NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 27     http://sharkattackfile.net/spreadsheets/pdf_di...  2018.04.15.c
# 76     http://sharkattackfile.net/spreadsheets/pdf_di...    2017.10.01
# 79     http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.24.b
# 84     http://sharkattackfile.net/spreadsheets/pdf_di...  2017.09.15.b
# 98     http://sharkattackfile.net/spreadsheets/pdf_di...  2017.08.26.b
# ...                                                  ...           ...
# 6307                                                 NaN           NaN
# 6308                                                 NaN           NaN
# 6309                                                 NaN           NaN
# 8702                                                 NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2  original order Unnamed: 22 Unnamed: 23 Fatal_adjusted
# 27     2018.04.15.c          6276.0         NaN         NaN  Non available
# 76       2017.10.01          6227.0         NaN         NaN              Y
# 79     2017.09.24.b          6224.0         NaN         NaN              N
# 84     2017.09.15.b          6219.0         NaN         NaN  Non available
# 98     2017.08.26.b          6205.0         NaN         NaN              N
# ...             ...             ...         ...         ...            ...
# 6307            NaN          6309.0         NaN         NaN  Non available
# 6308            NaN          6310.0         NaN         NaN  Non available
# 6309            NaN             NaN         NaN         NaN  Non available
# 8702            NaN             NaN         NaN         NaN  Non available
# 25722           NaN             NaN         NaN         NaN  Non available
#
# [549 rows x 25 columns]

# %% [markdown]
# ### Row dropping

# %%
# Let's drop the rows where Fatal_adjusted is Non available, through a list of indexes.

list_to_be_dropped = shark_attacks.loc[shark_attacks['Fatal_adjusted'] == 'Non available'].index

# Dropping the list of indexes
shark_attacks_v1 = shark_attacks.drop(index=list_to_be_dropped)

# %%
# Let's drop the case of 2017 (row 786).
case_2017_list = [786]

# %%
# Let's drop the case of UNKNOWNs ().
    # case_UNKNOWN_list
    
shark_attacks_v2 = shark_attacks_v1.drop(index=case_UNKNOWN_list)
shark_attacks_v3 = shark_attacks_v2.drop(index=case_2017_list)

# %% [markdown]
# ### Row adjusting

# %%
# For M, we will update the row 285 for Fatal (Y/N) from M to N.

shark_attacks_v3.loc[285,'Fatal_adjusted'] = 'N'

# Checking the value update:

print(shark_attacks_v3.loc[285,'Fatal_adjusted'])
# Out:
# N

# %% [markdown]
# ### Stripping spaces in Fatal_adjusted

# %%
def strip_spaces(x):
    return x.strip()    

shark_attacks_v3['Fatal_adjusted'] = shark_attacks_v3['Fatal_adjusted'].apply(strip_spaces)

# %%
set(shark_attacks_v3['Fatal_adjusted'])
# Out:
# {'N', 'Y', 'y'}

# %% [markdown]
# ### Upper case all strings in Fatal_adjusted

# %%
shark_attacks_v3['Fatal_adjusted'] = shark_attacks_v3['Fatal_adjusted'].str.upper()

# %%
set(shark_attacks_v3['Fatal_adjusted'])

# We obtained a set containing only 'N' and 'Y' at the end.
# Out:
# {'N', 'Y'}

# %%
# The database updated:

shark_attacks_v3['Fatal_adjusted'].value_counts()
# Out:
# N    4580
# Y    1620
# Name: Fatal_adjusted, dtype: int64

# %% [markdown]
# ### Total death rate (result)

# %%
death_rate = 1620/4580
print(f"""The total death rate for the time span was {death_rate*100}%. 
This number could be lower but hardly higher, since we dropped the columns where no conclusion could be drawn
and they were mostly about lacerations and such.""")
# Out:
# The total death rate for the time span was 35.37117903930131%.
# This number could be lower but hardly higher, since we dropped the columns where no conclusion could be drawn
# and they were mostly about lacerations and such.

# %%
shark_attacks_v3
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 0               Julie Wolfe    F   57
# 1           Adyson McNeely     F   11
# 2               John Denges    M   48
# 3                      male    M  NaN
# 4            Gustavo Ramos     M  NaN
# ...                     ...  ...  ...
# 6297                   male    M  NaN
# 6298                  Ahmun    M  NaN
# 6299  Coast Guard personnel    M  NaN
# 6300        Jules Patterson    M  NaN
# 6301                   male    M   15
#
#                                                  Injury Fatal (Y/N)  \
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                             Minor injury to lower leg           N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 6297                                              FATAL           Y
# 6298                                              FATAL           Y
# 6299                                              FATAL           Y
# 6300                                              FATAL           Y
# 6301  FATAL. "Shark bit him in half, carrying away t...           Y
#
#                Time         Species                  Investigator or Source  \
# 0             18h00      White shark                       R. Collier, GSAF
# 1     14h00  -15h00              NaN         K.McMurray, TrackingSharks.com
# 2             07h45              NaN         K.McMurray, TrackingSharks.com
# 3               NaN        2 m shark                         B. Myatt, GSAF
# 4               NaN  Tiger shark, 3m                              A .Kipper
# ...             ...              ...                                    ...
# 6297            NaN              NaN       H. Taunton; N. Bartlett,  p. 234
# 6298            NaN              NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6299            NaN              NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6300            NaN              NaN                    The Sun, 10/20/1938
# 6301            NaN              NaN                             S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23 Fatal_adjusted
# 0       2018.06.25          6303.0         NaN         NaN              N
# 1       2018.06.18          6302.0         NaN         NaN              N
# 2       2018.06.09          6301.0         NaN         NaN              N
# 3       2018.06.08          6300.0         NaN         NaN              N
# 4       2018.06.04          6299.0         NaN         NaN              N
# ...            ...             ...         ...         ...            ...
# 6297       ND.0005             6.0         NaN         NaN              Y
# 6298       ND.0004             5.0         NaN         NaN              Y
# 6299       ND.0003             4.0         NaN         NaN              Y
# 6300       ND.0002             3.0         NaN         NaN              Y
# 6301       ND.0001             2.0         NaN         NaN              Y
#
# [6200 rows x 25 columns]

# %% [markdown]
# ## Data Cleaning: 'Activity'

# %% [markdown]
# ### Checking uniques.

# %%
# Let's check the unique values of the column Activity.

print(set(shark_attacks['Activity']))

# Problematic: anedoctal(too many descriptions).
# We will have to categorize them better, maybe through bins.
# Out:
# {nan, 'Surfing (lying prone on his board)', 'Free diving, hunting crayfish', 'Japanese freighter Bokuyo Maru burned & sank', 'Catching a turtle', 'Fisherman', 'Scuba diving (but on surface)', 'Swimming from makeshift raft  to life vest after fishing boat sank', 'Fishing, attempted to take a netted shark', 'Paddling on surfboard', 'Attempting to fix motor', 'Free diving / spearfishing, from paddleboard & floating on the surface', 'Beach seine netting', "Accidentally stood on hooked shark's tail before attempting to gut it ", 'Ocean racing', 'Cage Diving', 'Free diving but treading water at surface', 'Swimming, towing a kayak', 'Diving for pearls', 'Scuba diving (ascending using scooter)', 'Aircraft exploded', 'Fishing for yellowtail', 'Bathing alongside US Naval ship', 'Washing cooking pans', 'Sea Disaster, sinking of the fishing  launch Mavis', 'Canoeing', 'Paddle-skiing', 'Swimming near jetty', 'Windsurfing', 'The troopship Britannia was sunk by the German raider Thor', 'Dragging banana seeds through the shallows', 'Sitting in shallows', 'Swimming / shipwreck', 'Sight-seeing', 'Night Surfing', 'Surfing (or body boarding)', 'Known as The Battle of the Bismarck Sea :  8 Japanese destroyers guarding a convoy of 8 transports were attacked by 129 Allied fighters, 207 bombers & 3 squadrons of the Royal Australian Air Force. ', 'Kite Boarding', 'Rowing ', 'Floating on air mattress', 'Spearfishing / Scuba diving (at surface)', 'Fell overboard while fishing for sharks', 'Swimming ashore from a "filibuster"', 'Murdered', 'Walking in chest-deep water', "Sitting in bow of her father's 5 m boat", 'Sitting on surfboard', 'Washing sand off a speared fish', 'Hunting crayfish ', 'S.S. Marine Sulphur Queen, laden with molten sulphur was bound from Beaumont, Texas for Norfolk, VA, when she disappeared with 39 on board', 'Sea Disaster Sinking of ferryboat Christina', "Fishing from 34' boat when pulled overboard by hooked shark", 'Body Boarding', 'Spearfishing with Joe Turner (24). Shark attracted to speared halibut on belt of one diver, tried to bite Ide\x92s speargun & he shot it in the mouth', 'Wading & pushing dinghy toward  the shallows', 'Boogie boarding', 'Spearfishing / freediving', 'Bathing with sister', 'Jumped off surfboard & landed on the shark', 'Spearfishing & diving for paua', 'Feeding sharks', 'Sinking of the ferryboat Bongbong 1', 'Boat capsized', 'Shipwrecked; adrift on raft for 2 days & 2 nights', "Fell off surfboard 20' from shore", 'Free diving, carrying speargun', 'Sailing from Gingood, Misamis Oriental to Sagay (normally a 2-day voyage) capsized with 6 on board, three men were taken by sharks when they attempted to swim to shore.', 'On expedition filming a feature movie & standing on tripod', 'Diving for coins thrown from ship S.S. Moeraki', 'Knocked into the water', 'Snorkeling on surface', 'Floating in inner tube', 'Surfing on "chest board" (boogie board?)', "Standing on landed shark's tail", 'Escaping from Alacatraz', 'Body boarding', 'Attempting to attract dolphins', 'Free diving for sinkers', 'Swimming close to wharf', 'Floating', 'Collecting fish in military trap when bitten by captured shark that had been shot by soldiers with Garten', 'Fishing for sharks when he became entangled in net & fell overboard', 'Hunting turtle', 'Playing on a sandbar', 'Paddling on surfboard or body board', 'Fishing for snapper', 'Jerked overboard while pole fishing for tuna', 'Dived from dinghy to retrieve oar in heavy seas', 'Rescuing seaman after ship sunk by German raider', 'Attacked shark with fists', 'Swimming after their boat capsized', 'Removing fish from a trap', 'Dived naked into the water on a bet', 'Standing / Snorkeling', 'Fishing, two large sharks passed. He speared one and it bit him', 'Jumped overboard from Norwegian steamship Venator', 'Spearfishing (free diving)', 'Standing / Bathing', 'Fishing in waist-deep water', 'Fishing for cod', 'boat from City of Naples capsized', 'Japanese POW ship Arisan Maru with 1800 American p ...

# %%
print(f"""

We will base this on the following sources:

https://en.wikipedia.org/wiki/List_of_water_sports
https://www.themost10.com/popular-water-sports/

- Fishing: Fishing / Spearfishing / Deep sea fishing / Big game fishing
- Diving: Diving / Scuba Diving / Snorkeling / Freediving
- Surfing: Surfing
- Swimming: Swimming
- Parasailing: Parasailing
- Boats: Kayaking / Canoeing / Rafting / Boating
- Skiing: Jet Skiing / Water Skiing
- Wake: Wakeboarding / Wakesurfing
- Kite: Kitesurfing / Kiteboarding
- Motorized boats: Yachting / Ship
- Other activities

...and finally...

- Shark feeding

""")
# Out:
# We will base this on the following sources:
#
# https://en.wikipedia.org/wiki/List_of_water_sports
# https://www.themost10.com/popular-water-sports/
#
# - Fishing: Fishing / Spearfishing / Deep sea fishing / Big game fishing
# - Diving: Diving / Scuba Diving / Snorkeling / Freediving
# - Surfing: Surfing
# - Swimming: Swimming
# - Parasailing: Parasailing
# - Boats: Kayaking / Canoeing / Rafting / Boating
# - Skiing: Jet Skiing / Water Skiing
# - Wake: Wakeboarding / Wakesurfing
# - Kite: Kitesurfing / Kiteboarding
# - Motorized boats: Yachting / Ship
# - Other activities
#
# ...and finally...
#
# - Shark feeding

# %% [markdown]
# ### Classifying

# %%
shark_attacks['Activity'] = shark_attacks['Activity'].astype(str)

def activity_classifier(row):
    """
    This function will classify the rows present in columns 'Activity' based on a list of strings set before.  
    """
    
    feeding_match_list = re.findall('[fF][eE][eE[dD]\w*', row['Activity'])
    fishing_match_list = re.findall('[fF][iI][sS][hH][iI]\w*', row['Activity'])
    diving_match_list = re.findall('[dD][iI][vV]\w*', row['Activity'])
    surfing_match_list = re.findall('[sS][uU][rR][fF]\w*', row['Activity'])
    swimming_match_list = re.findall('[sS][wW][iI][mM]\w*', row['Activity'])
    parasailing_match_list = re.findall('[pP][aA][rR][aA][sS][aA][iI][lL]\w*', row['Activity'])
    skiing_match_list = re.findall('[sS][kK][iI]\w*', row['Activity'])
    wake_match_list = re.findall('[wW][aA][kK][eE]\w*', row['Activity'])
    kite_match_list = re.findall('[kK][iI][tT][eE]\w*', row['Activity'])
    boating_match_list = re.findall('[kKcCrRbB][aAoO][yYnNfFaA][aAoOtT][eE]?\w*', row['Activity'])
    motorized_match_list = re.findall('[yYsS][aAhH][tTiI][cCpP][hH]?\w*', row['Activity'])
    
    if  len(feeding_match_list) != 0:
        return feeding_match_list[0]
    
    elif len(fishing_match_list) != 0:
        return fishing_match_list[0]
    
    elif  len(diving_match_list) != 0:
        return diving_match_list[0]
        
    elif len(surfing_match_list) != 0:
        return surfing_match_list[0]
        
    elif len(swimming_match_list) != 0:
        return swimming_match_list[0]
    
    elif len(parasailing_match_list) != 0:
        return parasailing_match_list[0]
    
    elif len(skiing_match_list) != 0:
        return skiing_match_list[0]
    
    elif len(wake_match_list) !=0:
        return wake_match_list[0]
    
    elif len(kite_match_list) !=0:
        return kite_match_list[0]
    
    elif len(boating_match_list) != 0:
        return boating_match_list[0]
    
    elif len(motorized_match_list) != 0:
        return motorized_match_list[0]
    
    else:
        return 'Others'
    
    
shark_attacks_v3['Activity_adjusted'] = shark_attacks.apply(activity_classifier, axis = 1)

shark_attacks_v3
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 0               Julie Wolfe    F   57
# 1           Adyson McNeely     F   11
# 2               John Denges    M   48
# 3                      male    M  NaN
# 4            Gustavo Ramos     M  NaN
# ...                     ...  ...  ...
# 6297                   male    M  NaN
# 6298                  Ahmun    M  NaN
# 6299  Coast Guard personnel    M  NaN
# 6300        Jules Patterson    M  NaN
# 6301                   male    M   15
#
#                                                  Injury Fatal (Y/N)  \
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                             Minor injury to lower leg           N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 6297                                              FATAL           Y
# 6298                                              FATAL           Y
# 6299                                              FATAL           Y
# 6300                                              FATAL           Y
# 6301  FATAL. "Shark bit him in half, carrying away t...           Y
#
#                Time         Species                  Investigator or Source  \
# 0             18h00      White shark                       R. Collier, GSAF
# 1     14h00  -15h00              NaN         K.McMurray, TrackingSharks.com
# 2             07h45              NaN         K.McMurray, TrackingSharks.com
# 3               NaN        2 m shark                         B. Myatt, GSAF
# 4               NaN  Tiger shark, 3m                              A .Kipper
# ...             ...              ...                                    ...
# 6297            NaN              NaN       H. Taunton; N. Bartlett,  p. 234
# 6298            NaN              NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6299            NaN              NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6300            NaN              NaN                    The Sun, 10/20/1938
# 6301            NaN              NaN                             S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23 Fatal_adjusted  \
# 0       2018.06.25          6303.0         NaN         NaN              N
# 1       2018.06.18          6302.0         NaN         NaN              N
# 2       2018.06.09          6301.0         NaN         NaN              N
# 3       2018.06.08          6300.0         NaN         NaN              N
# 4       2018.06.04          6299.0         NaN         NaN              N
# ...            ...             ...         ...         ...            ...
# 6297       ND.0005             6.0         NaN         NaN              Y
# 6298       ND.0004             5.0         NaN         NaN              Y
# 6299       ND.0003             4.0         NaN         NaN              Y
# 6300       ND.0002             3.0         NaN         NaN              Y
# 6301       ND.0001             2.0         NaN         NaN              Y
#
#      Activity_adjusted
# 0               Others
# 1               Others
# 2              Surfing
# 3              Surfing
# 4               diving
# ...                ...
# 6297            Diving
# 6298            diving
# 6299          Swimming
# 6300            Others
# 6301          Swimming
#
# [6200 rows x 26 columns]

# %%
set(shark_attacks_v3['Activity_adjusted'])
# Out:
# {'Boat',
#  'Boating',
#  'Canada',
#  'Canoe',
#  'Canoeing',
#  'Dived',
#  'Diving',
#  'Feeding',
#  'Feeling',
#  'Fishing',
#  'Fishingat',
#  'Kayaking',
#  'Kite',
#  'Kiteboarding',
#  'Others',
#  'Raytheon',
#  'Royal',
#  'Ship',
#  'Shipwreck',
#  'Shipwrecked',
#  'Skiing',
#  'Skimboarding',
#  'Surf',
#  'Surfing',
#  'Surfng',
#  'Swimming',
#  'Wakeboarding',
#  'banana',
#  'bananas',
#  'boat',
#  'boating',
#  'boats',
#  'caft',
#  'canoe',
#  'canoeing',
#  'canoes',
#  'containing',
#  'contract',
#  'dive',
#  'dived',
#  'diver',
#  'divers',
#  'divians',
#  'diving',
#  'fed',
#  'feeding',
#  'feel',
#  'feet',
#  'fishing',
#  'fishingat',
#  'kite',
#  'raft',
#  'rafts',
#  'rant',
#  'roat',
#  'ronaut',
#  'rontenac',
#  'ship',
#  'shipmate',
#  'shipmates',
#  'ships',
#  'shipwreck',
#  'shipwrecked',
#  'ski',
#  'skiff',
#  'skiing',
#  'surf',
#  'surface',
#  'surfboard',
#  'surfboat',
#  'surfing',
#  'surfmat',
#  'swim',
#  'swimming',
#  'swimmng'}

# %%
"""
It is clear that we reduced the problem to some categories. Let's refine it.
"""

shark_attacks['Activity'] = shark_attacks['Activity'].astype(str).str.lower()

def activity_classifier(row):
    """
    This function will classify the rows present in columns 'Activity' based on a list of strings set before.  
    """
    
    feeding_match_list = re.findall('[f][e][e][d].*[s][h][a]', row['Activity'])
    fishing_match_list = re.findall('[f][i][s][h][i]', row['Activity'])
    diving_match_list = re.findall('[d][i][v]', row['Activity'])
    surfing_match_list = re.findall('[s][u][r][f]', row['Activity'])
    swimming_match_list = re.findall('[s][w][i][m]', row['Activity'])
    parasailing_match_list = re.findall('[p][a][r][a][s][a][i][l]', row['Activity'])
    skiing_match_list = re.findall('[s][k][i]', row['Activity'])
    wake_match_list = re.findall('[w][a][k][e]', row['Activity'])
    kite_match_list = re.findall('[k][i][t][e]', row['Activity'])
    boating_match_list = re.findall('[kcrb][ao][ynfa][aot]', row['Activity'])
    motorized_match_list = re.findall('[ys][ah][ti][cp][h]?', row['Activity'])
    
    if  len(feeding_match_list) != 0:
        return feeding_match_list[0]
    
    elif len(fishing_match_list) != 0:
        return fishing_match_list[0]
    
    elif  len(diving_match_list) != 0:
        return diving_match_list[0]
        
    elif len(surfing_match_list) != 0:
        return surfing_match_list[0]
        
    elif len(swimming_match_list) != 0:
        return swimming_match_list[0]
    
    elif len(parasailing_match_list) != 0:
        return parasailing_match_list[0]
    
    elif len(skiing_match_list) != 0:
        return skiing_match_list[0]
    
    elif len(wake_match_list) !=0:
        return wake_match_list[0]
    
    elif len(kite_match_list) !=0:
        return kite_match_list[0]
    
    elif len(boating_match_list) != 0:
        return boating_match_list[0]
    
    elif len(motorized_match_list) != 0:
        return motorized_match_list[0]
    
    else:
        return 'other activities'

    
shark_attacks_v3['Activity_adjusted'] = shark_attacks.apply(activity_classifier, axis = 1)

shark_attacks_v3
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 0               Julie Wolfe    F   57
# 1           Adyson McNeely     F   11
# 2               John Denges    M   48
# 3                      male    M  NaN
# 4            Gustavo Ramos     M  NaN
# ...                     ...  ...  ...
# 6297                   male    M  NaN
# 6298                  Ahmun    M  NaN
# 6299  Coast Guard personnel    M  NaN
# 6300        Jules Patterson    M  NaN
# 6301                   male    M   15
#
#                                                  Injury Fatal (Y/N)  \
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                             Minor injury to lower leg           N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 6297                                              FATAL           Y
# 6298                                              FATAL           Y
# 6299                                              FATAL           Y
# 6300                                              FATAL           Y
# 6301  FATAL. "Shark bit him in half, carrying away t...           Y
#
#                Time         Species                  Investigator or Source  \
# 0             18h00      White shark                       R. Collier, GSAF
# 1     14h00  -15h00              NaN         K.McMurray, TrackingSharks.com
# 2             07h45              NaN         K.McMurray, TrackingSharks.com
# 3               NaN        2 m shark                         B. Myatt, GSAF
# 4               NaN  Tiger shark, 3m                              A .Kipper
# ...             ...              ...                                    ...
# 6297            NaN              NaN       H. Taunton; N. Bartlett,  p. 234
# 6298            NaN              NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6299            NaN              NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6300            NaN              NaN                    The Sun, 10/20/1938
# 6301            NaN              NaN                             S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23 Fatal_adjusted  \
# 0       2018.06.25          6303.0         NaN         NaN              N
# 1       2018.06.18          6302.0         NaN         NaN              N
# 2       2018.06.09          6301.0         NaN         NaN              N
# 3       2018.06.08          6300.0         NaN         NaN              N
# 4       2018.06.04          6299.0         NaN         NaN              N
# ...            ...             ...         ...         ...            ...
# 6297       ND.0005             6.0         NaN         NaN              Y
# 6298       ND.0004             5.0         NaN         NaN              Y
# 6299       ND.0003             4.0         NaN         NaN              Y
# 6300       ND.0002             3.0         NaN         NaN              Y
# 6301       ND.0001             2.0         NaN         NaN              Y
#
#      Activity_adjusted
# 0     other activities
# 1     other activities
# 2                 surf
# 3                 surf
# 4                  div
# ...                ...
# 6297               div
# 6298               div
# 6299              swim
# 6300  other activities
# 6301              swim
#
# [6200 rows x 26 columns]

# %%
set(shark_attacks_v3['Activity_adjusted'])
# Out:
# {'bana',
#  'boat',
#  'caft',
#  'cana',
#  'cano',
#  'cont',
#  'div',
#  "feeding 2.5' to 5\x92 sha",
#  'feeding a sha',
#  'feeding captive sha',
#  'feeding mullet to sha',
#  'feeding prawns to captive sha',
#  'feeding sha',
#  'feeding the sha',
#  'fishi',
#  'kaya',
#  'kite',
#  'other activities',
#  'raft',
#  'rant',
#  'rayt',
#  'roat',
#  'rona',
#  'ront',
#  'roya',
#  'ship',
#  'ski',
#  'surf',
#  'swim',
#  'wake'}

# %%
"""
Now that we narrowed down, we will classify them.
"""

shark_attacks['Activity'] = shark_attacks['Activity'].astype(str).str.lower()

def activity_classifier(row):
    """
    This function will classify the rows present in columns 'Activity' based on a list of strings set before.  
    """
    
    feeding_match_list = re.findall('[f][e][e[d].*[s][h][a]', row['Activity'])
    fishing_match_list = re.findall('[f][i][s][h][i]', row['Activity'])
    diving_match_list = re.findall('[d][i][v]', row['Activity'])
    surfing_match_list = re.findall('[s][u][r][f]', row['Activity'])
    swimming_match_list = re.findall('[s][w][i][m]', row['Activity'])
    parasailing_match_list = re.findall('[p][a][r][a][s][a][i][l]', row['Activity'])
    skiing_match_list = re.findall('[s][k][i]', row['Activity'])
    wake_match_list = re.findall('[w][a][k][e]', row['Activity'])
    kite_match_list = re.findall('[k][i][t][e]', row['Activity'])
    boating_match_list = re.findall('[kcrb][ao][ynfa][aot]', row['Activity'])
    motorized_match_list = re.findall('[ys][ah][ti][cp][h]?', row['Activity'])
    
    if  len(feeding_match_list) != 0:
        return 'feeding'
    
    elif len(fishing_match_list) != 0:
        return 'fishing'
                
    elif  len(diving_match_list) != 0:
        return 'diving'
        
    elif len(surfing_match_list) != 0:
        return 'surfing'
        
    elif len(swimming_match_list) != 0:
        return 'swimming'
    
    elif len(parasailing_match_list) != 0:
        return 'parasailing'
    
    elif len(skiing_match_list) != 0:
        return 'skiing'
    
    elif len(wake_match_list) !=0:
        return 'wake'
    
    elif len(kite_match_list) !=0:
        return 'kite'
    
    elif len(boating_match_list) != 0:
        return 'boating'
    
    elif len(motorized_match_list) != 0:
        return 'yatching/ship'
    
    else:
        return 'other activities'

    
shark_attacks_v3['Activity_adjusted'] = shark_attacks.apply(activity_classifier, axis = 1)

shark_attacks_v3
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# 0            California          Oceanside, San Diego County      Paddling
# 1               Georgia       St. Simon Island, Glynn County      Standing
# 2                Hawaii                         Habush, Oahu       Surfing
# 3       New South Wales                   Arrawarra Headland       Surfing
# 4                Colima                             La Ticla   Free diving
# ...                 ...                                  ...           ...
# 6297  Western Australia                          Roebuck Bay        Diving
# 6298  Western Australia                                  NaN  Pearl diving
# 6299     North Carolina                       Ocracoke Inlet      Swimming
# 6300                NaN                 Panama Bay 8ºN, 79ºW           NaN
# 6301   Eastern Province  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 0               Julie Wolfe    F   57
# 1           Adyson McNeely     F   11
# 2               John Denges    M   48
# 3                      male    M  NaN
# 4            Gustavo Ramos     M  NaN
# ...                     ...  ...  ...
# 6297                   male    M  NaN
# 6298                  Ahmun    M  NaN
# 6299  Coast Guard personnel    M  NaN
# 6300        Jules Patterson    M  NaN
# 6301                   male    M   15
#
#                                                  Injury Fatal (Y/N)  \
# 0     No injury to occupant, outrigger canoe and pad...           N
# 1                            Minor injury to left thigh           N
# 2          Injury to left lower leg from surfboard skeg           N
# 3                             Minor injury to lower leg           N
# 4     Lacerations to leg & hand shark PROVOKED INCIDENT           N
# ...                                                 ...         ...
# 6297                                              FATAL           Y
# 6298                                              FATAL           Y
# 6299                                              FATAL           Y
# 6300                                              FATAL           Y
# 6301  FATAL. "Shark bit him in half, carrying away t...           Y
#
#                Time         Species                  Investigator or Source  \
# 0             18h00      White shark                       R. Collier, GSAF
# 1     14h00  -15h00              NaN         K.McMurray, TrackingSharks.com
# 2             07h45              NaN         K.McMurray, TrackingSharks.com
# 3               NaN        2 m shark                         B. Myatt, GSAF
# 4               NaN  Tiger shark, 3m                              A .Kipper
# ...             ...              ...                                    ...
# 6297            NaN              NaN       H. Taunton; N. Bartlett,  p. 234
# 6298            NaN              NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 6299            NaN              NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 6300            NaN              NaN                    The Sun, 10/20/1938
# 6301            NaN              NaN                             S.W. Baker
#
#                                  pdf  \
# 0               2018.06.25-Wolfe.pdf
# 1             2018.06.18-McNeely.pdf
# 2              2018.06.09-Denges.pdf
# 3           2018.06.08-Arrawarra.pdf
# 4               2018.06.04-Ramos.pdf
# ...                              ...
# 6297          ND-0005-RoebuckBay.pdf
# 6298               ND-0004-Ahmun.pdf
# 6299  ND-0003-Ocracoke_1900-1905.pdf
# 6300      ND-0002-JulesPatterson.pdf
# 6301              ND-0001-Ceylon.pdf
#
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                 ...           ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0002
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23 Fatal_adjusted  \
# 0       2018.06.25          6303.0         NaN         NaN              N
# 1       2018.06.18          6302.0         NaN         NaN              N
# 2       2018.06.09          6301.0         NaN         NaN              N
# 3       2018.06.08          6300.0         NaN         NaN              N
# 4       2018.06.04          6299.0         NaN         NaN              N
# ...            ...             ...         ...         ...            ...
# 6297       ND.0005             6.0         NaN         NaN              Y
# 6298       ND.0004             5.0         NaN         NaN              Y
# 6299       ND.0003             4.0         NaN         NaN              Y
# 6300       ND.0002             3.0         NaN         NaN              Y
# 6301       ND.0001             2.0         NaN         NaN              Y
#
#      Activity_adjusted
# 0     other activities
# 1     other activities
# 2              surfing
# 3              surfing
# 4               diving
# ...                ...
# 6297            diving
# 6298            diving
# 6299          swimming
# 6300  other activities
# 6301          swimming
#
# [6200 rows x 26 columns]

# %%
set(shark_attacks_v3['Activity_adjusted'])
# Out:
# {'boating',
#  'diving',
#  'feeding',
#  'fishing',
#  'kite',
#  'other activities',
#  'skiing',
#  'surfing',
#  'swimming',
#  'wake',
#  'yatching/ship'}

# %%
# Let's check the results of the classification.

shark_attacks_v3[shark_attacks_v3['Activity_adjusted'] == 'feeding']

# In general it's pretty good.
# Out:
#        Case Number                  Date    Year          Type  \
# 10      2018.05.24           24-May-2018  2018.0      Provoked
# 14      2018.05.00              May 2018  2018.0      Provoked
# 132   2017.06.14.R  Reported 14-Jun-2017  2017.0    Unprovoked
# 140     2017.05.28           28-May-2017  2017.0    Unprovoked
# 442     2015.03.16           16-Mar-2015  2015.0    Unprovoked
# 811   2012.03.06.a           06-Mar-2012  2012.0      Provoked
# 2073    2000.02.14           14-Feb-2000  2000.0      Provoked
# 2701  1989.00.00.b                  1989  1989.0    Unprovoked
# 3200    1975.12.02           02-Dec-1975  1975.0      Provoked
# 3235    1975.03.13           13-Mar-1975  1975.0      Provoked
# 3446    1968.12.26           26-Dec-1968  1968.0      Provoked
# 3527    1967.05.09           09-May-1967  1967.0      Provoked
# 4049    1959.11.10           10-Nov-1959  1959.0    Unprovoked
# 4720  1942.00.00.k                  1942  1942.0  Sea Disaster
# 5131    1927.02.14           14-Feb-1927  1927.0      Provoked
#
#                Country               Area  \
# 10           AUSTRALIA         Queensland
# 14           AUSTRALIA  Westerm Australia
# 132            BAHAMAS                NaN
# 140                USA            Florida
# 442   FRENCH POLYNESIA          Bora Bora
# 811          AUSTRALIA           Victoria
# 2073           ENGLAND     Worcestershire
# 2701  PAPUA NEW GUINEA        New Ireland
# 3200         AUSTRALIA    New South Wales
# 3235         AUSTRALIA         Queensland
# 3446         AUSTRALIA    New South Wales
# 3527         AUSTRALIA                NaN
# 4049               USA         California
# 4720         INDONESIA          East Java
# 5131         NICARAGUA        Salinas Bay
#
#                                                Location  \
# 10                                      Cairns Aquarium
# 14                                           Dugong Bay
# 132                                                 NaN
# 140                                         Off Jupiter
# 442                                                Anau
# 811                  Shipwreck Cove, Melbourne Aquarium
# 2073                  The Fountain Pub in Tenbury Wells
# 2701                                            Kavieng
# 3200                         Porpoise Pool, Tweed Heads
# 3235                                 Southport Aquarium
# 3446                Marineland Aquarium, Manley, Sydney
# 3527                                           Aquarium
# 4049     Near Paradise Cove, Malibu, Los Angeles County
# 4720                                           Surabaya
# 5131  A shark was caught, its head severed from body...
#
#                                                Activity                Name  \
# 10                                       Feeding sharks                male
# 14                                       Feeding sharks     Melisa Brunning
# 132                                      Feeding sharks               Carly
# 140                                      Feeding sharks        Randy Jordan
# 442                                 Hand feeding sharks                male
# 811                              Diving, feeding sharks              female
# 2073                   Feeding prawns to captive sharks  Paul Smith, a chef
# 2701                  Scuba diving, hand feeding sharks      Dinah Halstead
# 3200                   Filming & feeding captive sharks         John Strand
# 3235                   Diving & force-feeding the shark     William Hookway
# 3446                           Feeding mullet to sharks         Peter Jones
# 3527                                    Feeding a shark         Rod Stanley
# 4049  Swimming at surface through school of feeding ...      Duffie Fryling
# 4720  Captured Allied soldiers were squeezed into 3'...        200 soldiers
# 5131                          Feeling the sharks teeth            a sailor
#
#      Sex   Age                                             Injury Fatal (Y/N)  \
# 10      M   32  Minor bite to hand by captive shark. PROVOKED ...           N
# 14      F   34    Shallow lacerations to finger PROVOKED INCIDENT           N
# 132     F  NaN                             Fingernail pulled off            N
# 140     M  NaN                           Lacerations to right arm           N
# 442     M    9                                        Hand bitten           N
# 811     F   34  Superficial lacerations to right side of face ...           N
# 2073    M  NaN                   Fingers bitten PROVOKED INCIDENT           N
# 2701    F  NaN                                Thigh & calf bitten           N
# 3200    M   35         Tooth mark in left elbow PROVOKED INCIDENT           N
# 3235  NaN   18  Laceration to thigh by captive shark PROVOKED ...           N
# 3446    M   27  Laceration to finger by a captive shark PROVOK...           N
# 3527    M   22                      Recorded as PROVOKED INCIDENT           N
# 4049    M   21                                     Forearm bitten           N
# 4720    M  NaN  General Imamura, Commander in Chief of Japanes...           Y
# 5131    M  NaN  Sharkss jaws snapped shut, lacerating his rig...           N
#
#                 Time                                           Species   \
# 10           Morning                                    Grey reef shark
# 14               NaN                              Tawny nurse shark, 2m
# 132              NaN                                                NaN
# 140          Morning                                        Tiger shark
# 442            10h00                                     Blacktip shark
# 811            11h30                            Tawny nurse shark, 40cm
# 2073             NaN  Miami, a 60 cm blacktip  shark and two 60 cm b...
# 2701             NaN                                 7' silvertip shark
# 3200             NaN                             Grey nurse shark, 10'
# 3235             NaN                            Bronze whaler shark, 6'
# 3446         Morning                             Grey nurse shark, 10'
# 3527       Afternoon                                   Grey nurse shark
# 4049  10h30 or 13h30                            Blue shark, 1.5 m [5']
# 4720             NaN                                                NaN
# 5131             NaN                                                NaN
#
#                                  Investigator or Source  \
# 10                               ABC.net.au ,05/24/2018
# 14                                 Perth Now, 6/30/2018
# 132                                   AOL.UK, 6/14/2017
# 140                                 M. Michaelson, GSAF
# 442                                   Radio1, 3/16/2015
# 811                                   The Age, 3/6/2012
# 2073                        The Sun (London), 2/17/2000
# 2701                                  S. Waterman, GSAF
# 3200                                     J. Green, p.36
# 3235                                 The Age, 3/14/1975
# 3446                                The Age, 12/27/1968
# 3527                H.D.Baldridge (1994) SAF Case #1536
# 4049  D. Miller & R. Collier; R. Collier, pp.26-27; ...
# 4720                                          G. Duncan
# 5131                                  G.A. Llano, p.178
#
#                                      pdf  \
# 10         2018.05.24-CairnsAquarium.pdf
# 14               2018.05.00-Brunning.pdf
# 132               2017.06.14.R-Carly.pdf
# 140                2017.05.28-Jordan.pdf
# 442             2015.03.16-Bora-Bora.pdf
# 811   2012.03.06.a-MelbourneAquarium.pdf
# 2073                2000.02.14-Smith.pdf
# 2701               1989.00.00.b-Halstead
# 3200               1975.12.02-Strand.pdf
# 3235              1975.03.13-Hookway.pdf
# 3446                1968.12.26-Jones.pdf
# 3527           1967.05.09-NV-Stanley.pdf
# 4049      1959.11.10-Fryling_Collier.pdf
# 4720  1942.00.00.k-PigBasketAtrocity.pdf
# 5131               1927.02.14-sailor.pdf
#
#                                            href formula  \
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...
# 132   http://sharkattackfile.net/spreadsheets/pdf_di...
# 140   http://sharkattackfile.net/spreadsheets/pdf_di...
# 442   http://sharkattackfile.net/spreadsheets/pdf_di...
# 811   http://sharkattackfile.net/spreadsheets/pdf_di...
# 2073  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2701  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3200  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3235  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3446  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3527  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4049  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4720  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5131  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 10    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.24
# 14    http://sharkattackfile.net/spreadsheets/pdf_di...    2018.05.00
# 132   http://sharkattackfile.net/spreadsheets/pdf_di...  2017.06.14.R
# 140   http://sharkattackfile.net/spreadsheets/pdf_di...    2017.05.28
# 442   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.03.16
# 811   http://sharkattackfile.net/spreadsheets/pdf_di...  2012.03.06.a
# 2073  http://sharkattackfile.net/spreadsheets/pdf_di...    2000.02.14
# 2701  http://sharkattackfile.net/spreadsheets/pdf_di...  1989.00.00.b
# 3200  http://sharkattackfile.net/spreadsheets/pdf_di...    1975.12.02
# 3235  http://sharkattackfile.net/spreadsheets/pdf_di...    1975.03.13
# 3446  http://sharkattackfile.net/spreadsheets/pdf_di...    1968.12.26
# 3527  http://sharkattackfile.net/spreadsheets/pdf_di...    1967.05.09
# 4049  http://sharkattackfile.net/spreadsheets/pdf_di...    1959.11.10
# 4720  http://sharkattackfile.net/spreadsheets/pdf_di...  1942.00.00.k
# 5131  http://sharkattackfile.net/spreadsheets/pdf_di...    1927.02.14
#
#      Case Number.2  original order Unnamed: 22 Unnamed: 23 Fatal_adjusted  \
# 10      2018.05.24          6293.0         NaN         NaN              N
# 14      2018.05.00          6289.0         NaN         NaN              N
# 132   2017.06.14.R          6171.0         NaN         NaN              N
# 140     2017.05.28          6163.0         NaN         NaN              N
# 442     2015.03.16          5861.0         NaN         NaN              N
# 811   2012.03.06.a          5492.0         NaN         NaN              N
# 2073    2000.02.14          4230.0         NaN         NaN              N
# 2701  1989.00.00.b          3602.0         NaN         NaN              N
# 3200    1975.12.02          3103.0         NaN         NaN              N
# 3235    1975.03.13          3068.0         NaN         NaN              N
# 3446    1968.12.26          2857.0         NaN         NaN              N
# 3527    1967.05.09          2776.0         NaN         NaN              N
# 4049    1959.11.10          2254.0         NaN         NaN              N
# 4720  1942.00.00.k          1583.0         NaN         NaN              Y
# 5131    1927.02.14          1172.0         NaN         NaN              N
#
#      Activity_adjusted
# 10             feeding
# 14             feeding
# 132            feeding
# 140            feeding
# 442            feeding
# 811            feeding
# 2073           feeding
# 2701           feeding
# 3200           feeding
# 3235           feeding
# 3446           feeding
# 3527           feeding
# 4049           feeding
# 4720           feeding
# 5131           feeding

# %%
shark_attacks_v3[shark_attacks_v3['Activity_adjusted'] == 'feeding'].shape
# Out:
# (15, 26)

# %% [markdown]
# ## Conclusion

# %%
# We managed to filter down all the entries into feeding sharks.
# Now we can divide by the number of valid total entries and get the % shark incidents.

feeding_attacks_perc = round(15/6200*100, 2)

print(f'The percentage share of attacks while feeding sharks during the timespan is {feeding_attacks_perc}%.')
# Out:
# The percentage share of attacks while feeding sharks during the timespan is 0.42%.

# %%
# In parallel, the % of attacks during diving is:
shark_attacks_v3[shark_attacks_v3['Activity_adjusted'] == 'diving'].shape
# Out:
# (543, 26)

# %%
diving_attacks_perc = round(543/6200*100, 2)

print(f'The percentage share of attacks while feeding sharks during the timespan is {diving_attacks_perc}%.')
print("Therefore, the chance of a shark attack while feeding them is lower than diving itself.")
# Out:
# The percentage share of attacks while feeding sharks during the timespan is 8.76%.
# Therefore, the chance of a shark attack while feeding them is lower than diving itself.
